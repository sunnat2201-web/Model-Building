# %% [markdown]
# # Funksiya rewiev

# %%
import pandas as pd

# %%
df=pd.read_csv('jobs.csv')

# %%
df.head()
# Out:
#    Age Education_Level  Years_of_Experience       Industry  \
# 0   59        Master's                  6.0        Finance
# 1   44        Master's                 14.0  Manufacturing
# 2   36      Bachelor's                  7.0         Retail
# 3   27      Bachelor's                  6.0        Finance
# 4   49     High School                 12.0        Finance
#
#                 Job_Role Company_Size Job_Level  Routine_Task_Percentage  \
# 0             Accountant       Medium     Entry                     84.0
# 1  Production Supervisor        Small     Entry                     30.0
# 2          Store Manager       Medium    Senior                     12.0
# 3                Auditor        Large     Entry                     90.0
# 4                Auditor        Small     Entry                     49.0
#
#    Creativity_Requirement  Human_Interaction_Level AI_Adoption_Level  \
# 0                    21.0                       94            Medium
# 1                    84.0                       68               Low
# 2                    86.0                       71               Low
# 3                    18.0                       21            Medium
# 4                    52.0                       72            Medium
#
#    Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# 0                      5.0                      7.0
# 1                      2.0                      2.0
# 2                      0.0                      1.0
# 3                      3.0                     10.0
# 4                      5.0                     13.0
#
#    Tasks_Automated_Percentage  AI_Training_Hours Layoff_Risk
# 0                          40                 26        High
# 1                          14                  9         Low
# 2                           6                  3         Low
# 3                          67                 26        High
# 4                          26                 19      Medium

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  str
#  2   Years_of_Experience         19998 non-null  float64
#  3   Industry                    20000 non-null  str
#  4   Job_Role                    20000 non-null  str
#  5   Company_Size                19998 non-null  str
#  6   Job_Level                   19994 non-null  str
#  7   Routine_Task_Percentage     19995 non-null  float64
#  8   Creativity_Requirement      19998 non-null  float64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           19998 non-null  str
#  11  Number_of_AI_Tools_Used     19995 non-null  float64
#  12  AI_Usage_Hours_Per_Week     19995 non-null  float64
#  13  Tasks_Automated_Percentage  20000 non-null  int64
#  14  AI_Training_Hours           20000 non-null  int64
#  15  Layoff_Risk                 19998 non-null  str
# dtypes: float64(5), int64(4), str(7)
# memory usage: 2.4 MB

# %%
df.isnull().sum()
# Out:
# Age                           0
# Education_Level               0
# Years_of_Experience           2
# Industry                      0
# Job_Role                      0
# Company_Size                  2
# Job_Level                     6
# Routine_Task_Percentage       5
# Creativity_Requirement        2
# Human_Interaction_Level       0
# AI_Adoption_Level             2
# Number_of_AI_Tools_Used       5
# AI_Usage_Hours_Per_Week       5
# Tasks_Automated_Percentage    0
# AI_Training_Hours             0
# Layoff_Risk                   2
# dtype: int64

# %%
def toldir(df):
    for col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype=='str':
                df.fillna({col:df[col].mode()[0]},inplace=True)
            else:
                df.fillna({col:df[col].mean()},inplace=True)
    return df

# %%
df=toldir(df)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Education_Level               0
# Years_of_Experience           0
# Industry                      0
# Job_Role                      0
# Company_Size                  0
# Job_Level                     0
# Routine_Task_Percentage       0
# Creativity_Requirement        0
# Human_Interaction_Level       0
# AI_Adoption_Level             0
# Number_of_AI_Tools_Used       0
# AI_Usage_Hours_Per_Week       0
# Tasks_Automated_Percentage    0
# AI_Training_Hours             0
# Layoff_Risk                   0
# dtype: int64

# %%
df.nunique()
# Out:
# Age                            40
# Education_Level                 4
# Years_of_Experience            28
# Industry                        8
# Job_Role                       24
# Company_Size                    3
# Job_Level                       3
# Routine_Task_Percentage        86
# Creativity_Requirement        102
# Human_Interaction_Level        80
# AI_Adoption_Level               3
# Number_of_AI_Tools_Used        12
# AI_Usage_Hours_Per_Week        32
# Tasks_Automated_Percentage     90
# AI_Training_Hours              80
# Layoff_Risk                     3
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
encoder=LabelEncoder()
encoder
# Out:
# LabelEncoder()

# %%
def codla(df):
    for col in df.columns:
        if df[col].dtype=='str':
            
                df[col]=encoder.fit_transform(df[col])
    return(df)

# %%
codla(df)
# Out:
#        Age  Education_Level  Years_of_Experience  Industry  Job_Role  \
# 0       59                2                  6.0         1         1
# 1       44                2                 14.0         5        14
# 2       36                0                  7.0         6        19
# 3       27                0                  6.0         1         2
# 4       49                1                 12.0         1         2
# ...    ...              ...                  ...       ...       ...
# 19995   56                0                 10.0         6        17
# 19996   43                0                  9.0         5        14
# 19997   28                1                  7.0         7        21
# 19998   46                0                  3.0         5        15
# 19999   36                0                  5.0         6        19
#
#        Company_Size  Job_Level  Routine_Task_Percentage  \
# 0                 1          0                     84.0
# 1                 2          0                     30.0
# 2                 1          2                     12.0
# 3                 0          0                     90.0
# 4                 2          0                     49.0
# ...             ...        ...                      ...
# 19995             2          0                     29.0
# 19996             1          0                     87.0
# 19997             1          0                     91.0
# 19998             1          2                     76.0
# 19999             1          1                     45.0
#
#        Creativity_Requirement  Human_Interaction_Level  AI_Adoption_Level  \
# 0                        21.0                       94                  2
# 1                        84.0                       68                  1
# 2                        86.0                       71                  1
# 3                        18.0                       21                  2
# 4                        52.0                       72                  2
# ...                       ...                      ...                ...
# 19995                    62.0                       44                  1
# 19996                    20.0                       20                  0
# 19997                     2.0                       49                  2
# 19998                    40.0                       89                  2
# 19999                    65.0                       75                  1
#
#        Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# 0                          5.0                      7.0
# 1                          2.0                      2.0
# 2                          0.0                      1.0
# 3                          3.0                     10.0
# 4                          5.0                     13.0
# ...                        ...                      ...
# 19995                      0.0                      4.0
# 19996                      9.0                     23.0
# 19997                      2.0                     14.0
# 19998                      3.0                     13.0
# 19999                      1.0                      0.0
#
#        Tasks_Automated_Percentage  AI_Training_Hours  Layoff_Risk
# 0                              40                 26            0
# 1                              14                  9            1
# 2                               6                  3            1
# 3                              67                 26            0
# 4                              26                 19            2
# ...                           ...                ...          ...
# 19995                          16                  0            2
# 19996                          77                 67            0
# 19997                          55                 10            0
# 19998                          66                  5            2
# 19999                          30                  8            2
#
# [20000 rows x 16 columns]

# %%
df=codla(df)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         20000 non-null  int64
#  1   Education_Level             20000 non-null  int64
#  2   Years_of_Experience         20000 non-null  float64
#  3   Industry                    20000 non-null  int64
#  4   Job_Role                    20000 non-null  int64
#  5   Company_Size                20000 non-null  int64
#  6   Job_Level                   20000 non-null  int64
#  7   Routine_Task_Percentage     20000 non-null  float64
#  8   Creativity_Requirement      20000 non-null  float64
#  9   Human_Interaction_Level     20000 non-null  int64
#  10  AI_Adoption_Level           20000 non-null  int64
#  11  Number_of_AI_Tools_Used     20000 non-null  float64
#  12  AI_Usage_Hours_Per_Week     20000 non-null  float64
#  13  Tasks_Automated_Percentage  20000 non-null  int64
#  14  AI_Training_Hours           20000 non-null  int64
#  15  Layoff_Risk                 20000 non-null  int64
# dtypes: float64(5), int64(11)
# memory usage: 2.4 MB

# %% [markdown]
# # Algorithm

# %%
from sklearn.linear_model import LogisticRegression,LinearRegression

# %%
log_reg=LogisticRegression()
log_reg
# Out:
# LogisticRegression()

# %%
x=df.drop('Layoff_Risk',axis=1)

# %%
x
# Out:
#        Age  Education_Level  Years_of_Experience  Industry  Job_Role  \
# 0       59                2                  6.0         1         1
# 1       44                2                 14.0         5        14
# 2       36                0                  7.0         6        19
# 3       27                0                  6.0         1         2
# 4       49                1                 12.0         1         2
# ...    ...              ...                  ...       ...       ...
# 19995   56                0                 10.0         6        17
# 19996   43                0                  9.0         5        14
# 19997   28                1                  7.0         7        21
# 19998   46                0                  3.0         5        15
# 19999   36                0                  5.0         6        19
#
#        Company_Size  Job_Level  Routine_Task_Percentage  \
# 0                 1          0                     84.0
# 1                 2          0                     30.0
# 2                 1          2                     12.0
# 3                 0          0                     90.0
# 4                 2          0                     49.0
# ...             ...        ...                      ...
# 19995             2          0                     29.0
# 19996             1          0                     87.0
# 19997             1          0                     91.0
# 19998             1          2                     76.0
# 19999             1          1                     45.0
#
#        Creativity_Requirement  Human_Interaction_Level  AI_Adoption_Level  \
# 0                        21.0                       94                  2
# 1                        84.0                       68                  1
# 2                        86.0                       71                  1
# 3                        18.0                       21                  2
# 4                        52.0                       72                  2
# ...                       ...                      ...                ...
# 19995                    62.0                       44                  1
# 19996                    20.0                       20                  0
# 19997                     2.0                       49                  2
# 19998                    40.0                       89                  2
# 19999                    65.0                       75                  1
#
#        Number_of_AI_Tools_Used  AI_Usage_Hours_Per_Week  \
# 0                          5.0                      7.0
# 1                          2.0                      2.0
# 2                          0.0                      1.0
# 3                          3.0                     10.0
# 4                          5.0                     13.0
# ...                        ...                      ...
# 19995                      0.0                      4.0
# 19996                      9.0                     23.0
# 19997                      2.0                     14.0
# 19998                      3.0                     13.0
# 19999                      1.0                      0.0
#
#        Tasks_Automated_Percentage  AI_Training_Hours
# 0                              40                 26
# 1                              14                  9
# 2                               6                  3
# 3                              67                 26
# 4                              26                 19
# ...                           ...                ...
# 19995                          16                  0
# 19996                          77                 67
# 19997                          55                 10
# 19998                          66                  5
# 19999                          30                  8
#
# [20000 rows x 15 columns]

# %%
y=df['Layoff_Risk']

# %% [markdown]
# # train

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (16000, 15)

# %%
log_reg.fit(x_train,y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # prediction

# %%
y_pred=log_reg.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 2, ..., 2, 2, 1], shape=(4000,))

# %% [markdown]
# # evaluation

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
class_report=classification_report(y_test,y_pred)

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88      1375
#            1       0.86      0.88      0.87      1296
#            2       0.75      0.71      0.73      1329
#
#     accuracy                           0.83      4000
#    macro avg       0.82      0.83      0.82      4000
# weighted avg       0.82      0.83      0.83      4000

# %% [markdown]
# # Vazifa

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
y_actual=[1,0,0,1,0,1,1,0,1]
y_predict=[1,0,1,0,0,1,0,0,1]
cm=confusion_matrix(y_actual,y_predict)

# %%
cm
# Out:
# array([[3, 1],
#        [2, 3]])

# %%
c_report=classification_report(y_actual,y_predict)

# %%
print(c_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         4
#            1       0.75      0.60      0.67         5
#
#     accuracy                           0.67         9
#    macro avg       0.68      0.68      0.67         9
# weighted avg       0.68      0.67      0.67         9
